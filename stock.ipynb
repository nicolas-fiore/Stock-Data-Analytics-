# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

aapl_stock = pd.read_excel('aaplStock.xlsx', index_col = None, na_values=['NA'])
aapl_stock.head()
# Out:
#         Date  Close/Last    Volume     Open     High      Low
# 0 2025-11-06      269.77  51204050  267.890  273.400  267.890
# 1 2025-11-05      270.14  43683070  268.610  271.700  266.930
# 2 2025-11-04      270.04  49274850  268.325  271.486  267.615
# 3 2025-11-03      269.05  50194580  270.420  270.850  266.250
# 4 2025-10-31      270.37  86167120  276.990  277.320  269.160

# %%
aapl_stock.describe()
# Out:
#                                 Date  Close/Last        Volume        Open  \
# count                            129  129.000000  1.290000e+02  129.000000
# mean   2025-08-06 23:37:40.465116160  226.017364  5.367516e+07  225.940930
# min              2025-05-06 00:00:00  195.270000  3.062125e+07  193.665000
# 25%              2025-06-23 00:00:00  203.920000  4.249664e+07  205.170000
# 50%              2025-08-07 00:00:00  220.030000  4.871394e+07  218.875000
# 75%              2025-09-23 00:00:00  247.450000  5.603866e+07  248.020000
# max              2025-11-06 00:00:00  271.400000  1.637413e+08  276.990000
# std                              NaN   23.431283  1.946771e+07   23.248719
#
#              High         Low
# count  129.000000  129.000000
# mean   228.125424  223.838999
# min    197.570000  193.250000
# 25%    207.880000  202.100000
# 50%    220.850000  216.580000
# 75%    249.040000  244.700000
# max    277.320000  269.160000
# std     23.403695   23.134656

# %%
plt.plot(aapl_stock['Date'], aapl_stock['Open'], label='Open Price')
plt.plot(aapl_stock['Date'], aapl_stock['Close/Last'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('AAPL Stock Prices Over Time')
plt.xticks(rotation=45)  # Rotate dates for readability
plt.legend() #box aka legend
plt.show()
